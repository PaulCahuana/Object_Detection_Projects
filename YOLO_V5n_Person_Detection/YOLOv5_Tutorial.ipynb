# %% [markdown]
# <a align="left" href="https://ultralytics.com/yolov5" target="_blank">
# <img src="https://user-images.githubusercontent.com/26833433/125273437-35b3fc00-e30d-11eb-9079-46f313325424.png"></a>
#
# This is the **official YOLOv5 🚀 notebook** authored by **Ultralytics**, and is freely available for redistribution under the [GPL-3.0 license](https://choosealicense.com/licenses/gpl-3.0/).
# For more information please visit https://github.com/ultralytics/yolov5 and https://ultralytics.com. Thank you!

# %% [markdown]
# # Setup
#
# Clone repo, install dependencies and check PyTorch and GPU.

# %%
#!git clone https://github.com/ultralytics/yolov5  # clone repo
#%cd yolov5
#%pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.9.0+cu102 (NVIDIA GeForce GTX 1660 SUPER)

# %% [markdown]
# # 1. Inference
#
# `detect.py` runs YOLOv5 inference on a variety of sources, downloading models automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and saving results to `runs/detect`. Example inference sources are:
#
# <img src="https://user-images.githubusercontent.com/26833433/114307955-5c7e4e80-9ae2-11eb-9f50-a90e39bee53f.png" width="900">

# %%
import time
start = time.time() #tomamos medida del tiempo

# !python yolov5/detect.py --weights RESULTADO/comp2/train/exp3/weights/last.pt --img 640 --conf 0.40 --source videos/arr3.avi
end = time.time() #paramos el tiempo
hours, rem = divmod(end-start, 3600)
minutes, seconds = divmod(rem, 60)
print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))
# Out:
# detect: weights=['RESULTADO/comp2/train/exp3/weights/last.pt'], source=videos/arr3.avi, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-115-gbc48457 torch 1.9.0+cu102 CUDA:0 (NVIDIA GeForce GTX 1660 SUPER, 5942MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 1760518 parameters, 0 gradients, 4.2 GFLOPs
# [avi @ 0x557aad1da8c0] Something went wrong during header parsing, tag [0][0][0][0] has size 1414744396, I will ignore it and try to continue anyway.
# [rawvideo @ 0x557b3240d780] Invalid pixel format.
# video 1/1 (1/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.009s)
# video 1/1 (2/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (3/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (4/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (5/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.008s)
# video 1/1 (6/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (7/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (8/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (9/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (10/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (11/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (12/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.009s)
# video 1/1 (13/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.008s)
# video 1/1 (14/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (15/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (16/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (17/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (18/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (19/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (20/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (21/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (22/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (23/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (24/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (25/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (26/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (27/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (28/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (29/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (30/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (31/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (32/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (33/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (34/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (35/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (36/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (37/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (38/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (39/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (40/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (41/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (42/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (43/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (44/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (45/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (46/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (47/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (48/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (49/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.009s)
# video 1/1 (50/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (51/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (52/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (53/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (54/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (55/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (56/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (57/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (58/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (59/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (60/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (61/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (62/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (63/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (64/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.009s)
# video 1/1 (65/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (66/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (67/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (68/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (69/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (70/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (71/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (72/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (73/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (74/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (75/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (76/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (77/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (78/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.008s)
# video 1/1 (79/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (80/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (81/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (82/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (83/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (84/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (85/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (86/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (87/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (88/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (89/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (90/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (91/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (92/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (93/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (94/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (95/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (96/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (97/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (98/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (99/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (100/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.010s)
# video 1/1 (101/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (102/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (103/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (104/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (105/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.008s)
# video 1/1 (106/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (107/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (108/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (109/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (110/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (111/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (112/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (113/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (114/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (115/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (116/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (117/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (118/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (119/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (120/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.008s)
# video 1/1 (121/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (122/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (123/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.008s)
# video 1/1 (124/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (125/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (126/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (127/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (128/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (129/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.008s)
# video 1/1 (130/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (131/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (132/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (133/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (134/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (135/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (136/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (137/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (138/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (139/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (140/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (141/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.008s)
# video 1/1 (142/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (143/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (144/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (145/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (146/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (147/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (148/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (149/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (150/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (151/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.008s)
# video 1/1 (152/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.008s)
# video 1/1 (153/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (154/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (155/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (156/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (157/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (158/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (159/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.008s)
# video 1/1 (160/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.008s)
# video 1/1 (161/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (162/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (163/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (164/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (165/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (166/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (167/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (168/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (169/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (170/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.009s)
# video 1/1 (171/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (172/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (173/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (174/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (175/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (176/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (177/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (178/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (179/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (180/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (181/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (182/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (183/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (184/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (185/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (186/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (187/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (188/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (189/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (190/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (191/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (192/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (193/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (194/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (195/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (196/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (197/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (198/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (199/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (200/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (201/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (202/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (203/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (204/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (205/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (206/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (207/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (208/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (209/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (210/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (211/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (212/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (213/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (214/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (215/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (216/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (217/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (218/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (219/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (220/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (221/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (222/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (223/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (224/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (225/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (226/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (227/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (228/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (229/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (230/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (231/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (232/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (233/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (234/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (235/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (236/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (237/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (238/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (239/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (240/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (241/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (242/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (243/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (244/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (245/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (246/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (247/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (248/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (249/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (250/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (251/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (252/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (253/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (254/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (255/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.008s)
# video 1/1 (256/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (257/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (258/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (259/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (260/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (261/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (262/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (263/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.008s)
# video 1/1 (264/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (265/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (266/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (267/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (268/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (269/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (270/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (271/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (272/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (273/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (274/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (275/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (276/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (277/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (278/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (279/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (280/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (281/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (282/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (283/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (284/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (285/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (286/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (287/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (288/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (289/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (290/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (291/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (292/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (293/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (294/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (295/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (296/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (297/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (298/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (299/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (300/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (301/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (302/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (303/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (304/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (305/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (306/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (307/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (308/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (309/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (310/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (311/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (312/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (313/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (314/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 1 person, Done. (0.005s)
# video 1/1 (315/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (316/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (317/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 1 person, Done. (0.006s)
# ...
# video 1/1 (1654/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1655/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1656/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1657/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1658/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (1659/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (1660/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1661/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1662/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1663/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1664/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1665/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1666/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1667/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1668/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1669/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1670/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1671/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1672/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1673/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1674/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1675/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (1676/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1677/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (1678/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.008s)
# video 1/1 (1679/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1680/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1681/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1682/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1683/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1684/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.008s)
# video 1/1 (1685/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1686/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1687/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1688/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.007s)
# video 1/1 (1689/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1690/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1691/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1692/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1693/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1694/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1695/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1696/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1697/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1698/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1699/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1700/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1701/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1702/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1703/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1704/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1705/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1706/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1707/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1708/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1709/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1710/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1711/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (1712/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (1713/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1714/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1715/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1716/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (1717/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1718/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1719/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1720/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1721/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1722/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1723/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1724/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1725/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1726/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1727/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (1728/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1729/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1730/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1731/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1732/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1733/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (1734/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1735/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1736/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.006s)
# video 1/1 (1737/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1738/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1739/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1740/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1741/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1742/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1743/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1744/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1745/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1746/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1747/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1748/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1749/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1750/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1751/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1752/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1753/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1754/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1755/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1756/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1757/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# video 1/1 (1758/3507) /mnt/b544e4c4-877a-4cd8-a91d-85c44fafd63a/ANACONDA/LYTICA/YOLO/YOLOV5N_PERSON_DETECTION/videos/arr3.avi: 384x640 Done. (0.005s)
# Speed: 0.4ms pre-process, 5.8ms inference, 0.3ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5/runs/detect/exp5
# 00:01:54.52

# %% [markdown]
# # 2. Validate
# Validate a model's accuracy on [COCO](https://cocodataset.org/#home) val or test-dev datasets. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases). To show results by class use the `--verbose` flag. Note that `pycocotools` metrics may be ~1% better than the equivalent repo metrics, as is visible below, due to slight differences in mAP computation.

# %% [markdown]
# ## COCO val2017
# Download [COCO val 2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L14) dataset (1GB - 5000 images), and test model accuracy.

# %%
# Download COCO val2017
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco2017val.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../datasets && rm tmp.zip
# Out:
# HBox(children=(FloatProgress(value=0.0, max=819257867.0), HTML(value='')))

# %%
# Run YOLOv5x on COCO val2017
# !python val.py --weights yolov5x.pt --data coco.yaml --img 640 --iou 0.65 --half
# Out:
# Namespace(augment=False, batch_size=32, conf_thres=0.001, data='./data/coco.yaml', device='', exist_ok=False, half=True, img_size=640, iou_thres=0.65, name='exp', project='runs/val', save_conf=False, save_hybrid=False, save_json=True, save_txt=False, single_cls=False, task='val', verbose=False, weights=['yolov5x.pt'])
# YOLOv5 🚀 v5.0-157-gc6b51f4 torch 1.8.1+cu101 CUDA:0 (Tesla V100-SXM2-16GB, 16160.5MB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v5.0/yolov5x.pt to yolov5x.pt...
# 100% 168M/168M [00:01<00:00, 156MB/s]
#
# Fusing layers...
# Model Summary: 476 layers, 87730285 parameters, 0 gradients
# val: Scanning '../coco/val2017' images and labels...4952 found, 48 missing, 0 empty, 0 corrupted: 100% 5000/5000 [00:01<00:00, 3008.87it/s]
# val: New cache created: ../coco/val2017.cache
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 157/157 [01:17<00:00,  2.02it/s]
#                  all       5000      36335      0.746      0.626       0.68       0.49
# Speed: 5.3/1.5/6.8 ms inference/NMS/total per 640x640 image at batch-size 32
#
# Evaluating pycocotools mAP... saving runs/val/exp/yolov5x_predictions.json...
# loading annotations into memory...
# Done (t=0.44s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=4.88s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=83.47s).
# Accumulating evaluation results...
# DONE (t=12.96s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.504
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.688
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.546
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.351
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.551
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.644
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.382
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.629
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.681
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.524
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.735
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.827
# Results saved to runs/val/exp

# %% [markdown]
# ## COCO test-dev2017
# Download [COCO test2017](https://github.com/ultralytics/yolov5/blob/74b34872fdf41941cddcf243951cdb090fbac17b/data/coco.yaml#L15) dataset (7GB - 40,000 images), to test model accuracy on test-dev set (**20,000 images, no labels**). Results are saved to a `*.json` file which should be **zipped** and submitted to the evaluation server at https://competitions.codalab.org/competitions/20794.

# %%
# Download COCO test-dev2017
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco2017labels.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../ && rm tmp.zip # unzip labels
# !f="test2017.zip" && curl http://images.cocodataset.org/zips/$f -o $f && unzip -q $f && rm $f  # 7GB,  41k images
# %mv ./test2017 ../coco/images  # move to /coco

# %%
# Run YOLOv5s on COCO test-dev2017 using --task test
# !python val.py --weights yolov5s.pt --data coco.yaml --task test

# %% [markdown]
# # 3. Train
#
# Download [COCO128](https://www.kaggle.com/ultralytics/coco128), a small 128-image tutorial dataset, start tensorboard and train YOLOv5s from a pretrained checkpoint for 3 epochs (note actual training is typically much longer, around **300-1000 epochs**, depending on your dataset).

# %%
# Download COCO128
torch.hub.download_url_to_file('https://github.com/ultralytics/yolov5/releases/download/v1.0/coco128.zip', 'tmp.zip')
# !unzip -q tmp.zip -d ../ && rm tmp.zip
# Out:
# HBox(children=(FloatProgress(value=0.0, max=22091032.0), HTML(value='')))

# %% [markdown]
# Train a YOLOv5s model on [COCO128](https://www.kaggle.com/ultralytics/coco128) with `--data coco128.yaml`, starting from pretrained `--weights yolov5s.pt`, or from randomly initialized `--weights '' --cfg yolov5s.yaml`. Models are downloaded automatically from the [latest YOLOv5 release](https://github.com/ultralytics/yolov5/releases), and **COCO, COCO128, and VOC datasets are downloaded automatically** on first use.
#
# All training results are saved to `runs/train/` with incrementing run directories, i.e. `runs/train/exp2`, `runs/train/exp3` etc.

# %%
# Tensorboard  (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
# Weights & Biases  (optional)
# %pip install -q wandb
import wandb
wandb.login()

# %%
# Train YOLOv5s on COCO128 for 3 epochs
#!python train.py --img 640 --batch 16 --epochs 3 --data coco128.yaml --weights yolov5s.pt --cache
# !python train.py --img 640 --batch 16 --epochs 50 --data custom_data.yaml  --cfg yolov5n.yaml --weights yolov5n.pt --cache
# Out:
# train: weights=yolov5n.pt, cfg=yolov5n.yaml, data=custom_data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: skipping check (offline), for updates see https://github.com/ultralytics/yolov5
# YOLOv5 🚀 v6.0-115-gbc48457 torch 1.9.0+cu102 CUDA:0 (NVIDIA GeForce GTX 1660 SUPER, 5942MiB)
#
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# 2021-12-01 18:06:08.355969: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/usr/local/cuda-11.1/lib64
# 2021-12-01 18:06:08.355996: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1760  models.common.Conv                      [3, 16, 6, 2, 2]
#   1                -1  1      4672  models.common.Conv                      [16, 32, 3, 2]
#   2                -1  1      4800  models.common.C3                        [32, 32, 1]
#   3                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   4                -1  2     29184  models.common.C3                        [64, 64, 2]
#   5                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   6                -1  3    156928  models.common.C3                        [128, 128, 3]
#   7                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   8                -1  1    296448  models.common.C3                        [256, 256, 1]
#   9                -1  1    164608  models.common.SPPF                      [256, 256, 5]
#  10                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  14                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     22912  models.common.C3                        [128, 64, 1, False]
#  18                -1  1     36992  models.common.Conv                      [64, 64, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1     74496  models.common.C3                        [128, 128, 1, False]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  24      [17, 20, 23]  1      8118  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [64, 128, 256]]
# Model Summary: 270 layers, 1765270 parameters, 1765270 gradients, 4.2 GFLOPs
#
# Transferred 342/349 items from yolov5n.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 57 weight, 60 weight (no decay), 60 bias
# train: Scanning '../train/labels/train.cache' images and labels... 2070 found, 0
# train: Caching images (1.4GB ram): 100%|███| 2070/2070 [00:12<00:00, 170.77it/s]
# val: Scanning '../train/labels/val' images and labels...591 found, 0 missing, 0
# val: New cache created: ../train/labels/val.cache
# val: Caching images (0.4GB ram): 100%|███████| 591/591 [00:03<00:00, 180.19it/s]
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# [W pthreadpool-cpp.cc:90] Warning: Leaking Caffe2 thread-pool after fork. (function pthreadpool)
# Plotting labels to runs/train/exp2/labels.jpg...
#
# AutoAnchor: 5.14 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/train/exp2
# Starting training for 50 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       0/49     1.75G   0.09381   0.06269         0        75       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        591       3088       0.65      0.509      0.532      0.192
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       1/49     1.95G   0.06716    0.0509         0        59       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        591       3088      0.636      0.499      0.563      0.244
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       2/49     1.95G   0.05923    0.0467         0        74       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        591       3088      0.786      0.648      0.776      0.404
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       3/49     1.95G   0.05388   0.04572         0        55       640: 100%|███
#                Class     Images     Labels          P          R     mAP@.5 mAP@
#                  all        591       3088      0.799      0.745      0.811      0.376
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#       4/49     1.95G   0.05621   0.04668         0       142       640:   9%|▉  ^C

# %% [markdown]
# # 4. Visualize

# %% [markdown]
# ## Weights & Biases Logging 🌟 NEW
#
# [Weights & Biases](https://wandb.ai/site?utm_campaign=repo_yolo_notebook) (W&B) is now integrated with YOLOv5 for real-time visualization and cloud logging of training runs. This allows for better run comparison and introspection, as well improved visibility and collaboration for teams. To enable W&B `pip install wandb`, and then train normally (you will be guided through setup on first use).
#
# During training you will see live updates at [https://wandb.ai/home](https://wandb.ai/home?utm_campaign=repo_yolo_notebook), and you can create and share detailed [Reports](https://wandb.ai/glenn-jocher/yolov5_tutorial/reports/YOLOv5-COCO128-Tutorial-Results--VmlldzozMDI5OTY) of your results. For more information see the [YOLOv5 Weights & Biases Tutorial](https://github.com/ultralytics/yolov5/issues/1289).
#
# <img src="https://user-images.githubusercontent.com/26833433/125274843-a27bc600-e30e-11eb-9a44-62af0b7a50a2.png" width="800">

# %% [markdown]
# ## Local Logging
#
# All results are logged by default to `runs/train`, with a new experiment directory created for each new training as `runs/train/exp2`, `runs/train/exp3`, etc. View train and val jpgs to see mosaics, labels, predictions and augmentation effects. Note a **Mosaic Dataloader** is used for training (shown below), a new concept developed by Ultralytics and first featured in [YOLOv4](https://arxiv.org/abs/2004.10934).

# %%
Image(filename='runs/train/exp/train_batch0.jpg', width=800)  # train batch 0 mosaics and labels
Image(filename='runs/train/exp/test_batch0_labels.jpg', width=800)  # val batch 0 labels
Image(filename='runs/train/exp/test_batch0_pred.jpg', width=800)  # val batch 0 predictions

# %% [markdown]
# > <img src="https://user-images.githubusercontent.com/26833433/124931219-48bf8700-e002-11eb-84f0-e05d95b118dd.jpg" width="700">
# `train_batch0.jpg` shows train batch 0 mosaics and labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/124931217-4826f080-e002-11eb-87b9-ae0925a8c94b.jpg" width="700">
# `test_batch0_labels.jpg` shows val batch 0 labels
#
# > <img src="https://user-images.githubusercontent.com/26833433/124931209-46f5c380-e002-11eb-9bd5-7a3de2be9851.jpg" width="700">
# `test_batch0_pred.jpg` shows val batch 0 _predictions_

# %% [markdown]
# Training results are automatically logged to [Tensorboard](https://www.tensorflow.org/tensorboard) and `runs/train/exp/results.txt`, which is plotted as `results.png` (below) after training completes. You can also plot any `results.txt` file manually:

# %%
from utils.plots import plot_results 
plot_results(save_dir='runs/train/exp')  # plot all results*.txt files in 'runs/train/exp'
Image(filename='runs/train/exp/results.png', width=800)

# %% [markdown]
# <p align="left"><img width="800" alt="COCO128 Training Results" src="https://user-images.githubusercontent.com/26833433/125273596-6300aa00-e30d-11eb-8dc4-70a960c53013.png"></p>

# %% [markdown]
# # Environments
#
# YOLOv5 may be run in any of the following up-to-date verified environments (with all dependencies including [CUDA](https://developer.nvidia.com/cuda)/[CUDNN](https://developer.nvidia.com/cudnn), [Python](https://www.python.org/) and [PyTorch](https://pytorch.org/) preinstalled):
#
# - **Google Colab and Kaggle** notebooks with free GPU: <a href="https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a> <a href="https://www.kaggle.com/ultralytics/yolov5"><img src="https://kaggle.com/static/images/open-in-kaggle.svg" alt="Open In Kaggle"></a>
# - **Google Cloud** Deep Learning VM. See [GCP Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/GCP-Quickstart)
# - **Amazon** Deep Learning AMI. See [AWS Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/AWS-Quickstart)
# - **Docker Image**. See [Docker Quickstart Guide](https://github.com/ultralytics/yolov5/wiki/Docker-Quickstart) <a href="https://hub.docker.com/r/ultralytics/yolov5"><img src="https://img.shields.io/docker/pulls/ultralytics/yolov5?logo=docker" alt="Docker Pulls"></a>

# %% [markdown]
# # Status
#
# ![CI CPU testing](https://github.com/ultralytics/yolov5/workflows/CI%20CPU%20testing/badge.svg)
#
# If this badge is green, all [YOLOv5 GitHub Actions](https://github.com/ultralytics/yolov5/actions) Continuous Integration (CI) tests are currently passing. CI tests verify correct operation of YOLOv5 training ([train.py](https://github.com/ultralytics/yolov5/blob/master/train.py)), testing ([val.py](https://github.com/ultralytics/yolov5/blob/master/val.py)), inference ([detect.py](https://github.com/ultralytics/yolov5/blob/master/detect.py)) and export ([export.py](https://github.com/ultralytics/yolov5/blob/master/export.py)) on MacOS, Windows, and Ubuntu every 24 hours and on every commit.

# %% [markdown]
# # Appendix
#
# Optional extras below. Unit tests validate repo functionality and should be run on any PRs submitted.

# %%
# Reproduce
for x in 'yolov5s', 'yolov5m', 'yolov5l', 'yolov5x':
  # !python val.py --weights {x}.pt --data coco.yaml --img 640 --conf 0.25 --iou 0.45  # speed
  # !python val.py --weights {x}.pt --data coco.yaml --img 640 --conf 0.001 --iou 0.65  # mAP

# %%
# PyTorch Hub
import torch

# Model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Images
dir = 'https://github.com/ultralytics/yolov5/raw/master/data/images/'
imgs = [dir + f for f in ('zidane.jpg', 'bus.jpg')]  # batch of images

# Inference
results = model(imgs)
results.print()  # or .show(), .save()

# %%
# Unit tests
# %%shell
export PYTHONPATH="$PWD"  # to run *.py. files in subdirectories

rm -rf runs  # remove runs/
for m in yolov5s; do  # models
  python train.py --weights $m.pt --epochs 3 --img 320 --device 0  # train pretrained
  python train.py --weights '' --cfg $m.yaml --epochs 3 --img 320 --device 0  # train scratch
  for d in 0 cpu; do  # devices
    python detect.py --weights $m.pt --device $d  # detect official
    python detect.py --weights runs/train/exp/weights/best.pt --device $d  # detect custom
    python val.py --weights $m.pt --device $d # val official
    python val.py --weights runs/train/exp/weights/best.pt --device $d # val custom
  done
  python hubconf.py  # hub
  python models/yolo.py --cfg $m.yaml  # inspect
  python export.py --weights $m.pt --img 640 --batch 1  # export
done

# %%
# Profile
from utils.torch_utils import profile 

m1 = lambda x: x * torch.sigmoid(x)
m2 = torch.nn.SiLU()
profile(x=torch.randn(16, 3, 640, 640), ops=[m1, m2], n=100)

# %%
# Evolve
# !python train.py --img 640 --batch 64 --epochs 100 --data coco128.yaml --weights yolov5s.pt --cache --noautoanchor --evolve
# !d=runs/train/evolve && cp evolve.* $d && zip -r evolve.zip $d && gsutil mv evolve.zip gs://bucket  # upload results (optional)

# %%
# VOC
for b, m in zip([64, 48, 32, 16], ['yolov5s', 'yolov5m', 'yolov5l', 'yolov5x']):  # zip(batch_size, model)
  # !python train.py --batch {b} --weights {m}.pt --data VOC.yaml --epochs 50 --cache --img 512 --nosave --hyp hyp.finetune.yaml --project VOC --name {m}
